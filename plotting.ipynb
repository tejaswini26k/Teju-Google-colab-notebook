# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswini26k/Teju-Google-colab-notebook/blob/main/plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %%
# %matplotlib inline

# %%
plt.style.use('classic')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,10])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %%
x=np.linspace(0,10,100)
fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')
fig.savefig('graph1.png')

# %%
x=np.linspace(0,10,100)
fig=plt.figure()
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')
fig.savefig('graph1.png')

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='-')
plt.plot(x,np.sin(x-1),color='g',linestyle='dashed')
plt.plot(x,np.sin(x-2),color='0.75',linestyle='dashdot')
plt.plot(x,np.sin(x-3),color='#FFDD44',linestyle='dotted')
plt.plot(x,np.sin(x-5),color=(1.0,0.2,0.3))

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.plot(x,np.sin(x-1),color='g')
plt.plot(x,np.sin(x-2),color='0.75')
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-5),color=(1.0,0.2,0.3))

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='solid')
plt.plot(x,np.sin(x-1),color='g',linestyle='dashed')
plt.plot(x,np.sin(x-2),color='0.75',)
plt.plot(x,np.sin(x-3),color='#FFDD44')
plt.plot(x,np.sin(x-3),color=(1.0,0.2,0.3))

# %%
plt.plot(x,np.sin(x-0),color='blue',linestyle='solid')
plt.plot(x,np.sin(x-1),color='g',linestyle='dashed')
plt.plot(x,np.sin(x-2),color='0.5',linestyle='dashdot')
plt.plot(x,np.sin(x-3),color='#AADDCC',linestyle='dotted')

# %%
import matplotlib.pyplot as plt
#sample datas
x=[1,2,3,4,5]#x axis values(time)
y=[10,15,7,12,9]

plt.plot(x,y,marker='o')

plt.title("line chart example")
plt.xlabel("time")
plt.ylabel("dependent variable")
plt.style.use('Solarize_Light2')


plt.show()

# %%
import matplotlib.pyplot as plt
#sample datas
categories=['day1','day2','day3','day 4']#x axis values(time)
values=[25,40,30,50]

plt.bar(categories,values)

plt.title("bar plot example")
plt.xlabel("categories")
plt.ylabel("values")



plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(170,10,250)
print(x)
plt.hist(x)
plt.show()
# Out:
# [196.17576746 166.39954328 169.2558502  165.77622731 176.55441208
#  179.77844787 168.36565403 170.76913004 157.52988226 146.32362779
#  178.22229944 162.0409993  168.57350085 180.25190844 173.56319682
#  162.81945836 164.8532721  167.64283945 161.0423731  182.67975983
#  194.04813517 180.3944529  167.96281644 173.33656515 159.80017284
#  166.27121201 162.6308532  180.39320496 172.69389772 170.55600042
#  159.23392621 176.86136481 160.48546514 156.86862863 181.1305142
#  170.43375746 170.92249825 179.13485285 172.82423233 173.89696698
#  175.14855921 167.41781133 178.95161296 174.20874673 161.1206733
#  150.89967721 173.17621464 157.2647852  155.06745378 153.95084422
#  172.51029982 171.48745215 169.15965435 137.97631035 175.17862447
#  156.90539    175.25174703 159.65809686 152.81966678 165.0481974
#  160.18496831 177.32611756 174.64183463 157.37587018 182.82502233
#  168.33310488 184.39954667 165.58170402 173.82633136 166.28586496
#  162.55599901 165.39746767 178.15822236 151.32313319 189.58789938
#  172.89389652 165.14512939 163.99265616 161.51265074 159.90756413
#  165.87040914 165.2560465  158.68353266 167.09919039 160.59944358
#  166.20167041 157.67111577 178.40239726 175.13499756 177.05119393
#  169.2590006  144.97600332 152.25909894 182.06696498 166.03308163
#  169.84656698 176.52470762 163.87754001 174.22319646 178.7652921
#  165.04291049 172.93563254 174.95571824 168.10656796 157.45876675
#  142.23351809 161.40084887 159.76872449 176.01038027 184.96340145
#  176.18692048 168.92527181 169.24287258 169.6673142  166.14031308
#  160.12224972 164.2745552  179.85891449 147.83114878 168.71493491
#  182.46118354 163.10262472 172.57815045 167.73425962 178.74547262
#  152.47016322 168.24286247 166.48913291 170.55459687 193.13682063
#  161.73865756 169.53627453 179.6274955  161.06009146 164.88776827
#  175.78376979 173.30823318 185.19980624 184.78926609 174.68580808
#  172.53128837 174.02484354 170.31449534 171.01836949 181.26536872
#  163.57997169 181.08569722 160.92474785 181.7095602  186.05428766
#  167.56185298 164.22635755 175.60683234 166.53341127 159.1223311
#  188.93755393 168.51464417 183.85993368 168.15461703 179.64124939
#  163.38463794 177.64023804 167.53350373 170.59637421 167.7144719
#  175.56310469 150.39944166 149.32875713 170.49028207 176.7746016
#  176.00622978 178.88056876 158.39359504 159.93047551 179.49614158
#  170.26691473 160.99509495 158.24261471 167.45031197 147.32878571
#  169.60622286 162.93388311 168.54119862 165.9374263  175.29842757
#  169.52218206 158.16282396 168.18584255 158.39701903 152.70308356
#  181.93614231 154.21376544 161.45091518 172.90219027 179.38901523
#  164.26137115 187.51698017 158.06458184 172.54750103 180.68271755
#  164.62870852 185.57986081 167.86102948 165.98240495 158.01736907
#  181.14229923 167.41715326 173.87401331 165.31447348 181.65129058
#  174.38185342 153.22839263 162.03627017 143.38084276 195.45301224
#  171.0740792  153.98803402 163.2009877  161.39273625 171.93662006
#  166.39319641 158.84762121 170.16639159 171.02559394 183.36216965
#  175.59545624 188.60502093 152.73456714 151.92108343 160.21764666
#  161.27132933 180.1112147  170.7023838  174.03583221 171.7232352
#  162.40663135 172.74076365 172.5508752  179.06569181 166.7585548
#  168.92328385 172.76656614 182.91920663 165.17188799 172.34061378
#  177.20616004 153.81751449 173.68845215 161.5497703  164.83946741]

# %%
x=np.arange(5)
y1=[34,56,12,87,54]
y2=[13,45,67,89,23]
width=0.4
plt.bar(x-0.2,y1,width)
plt.bar(x+0.2,y2,width)
plt.title("bar plot example")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.Dataframe([['a',10,20,30,40],['b',28,34,45,56],['c',34,23,45,65],['d',13,23,45,23]])
columns=(['team','round1','round2','round3','round4'])
print(df)
df.plot='team'
kind='bar',stacked==False,title('grouped bar graph with dataphrame')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-1aec27654975> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 df=pd.Dataframe([['a',10,20,30,40],['b',28,34,45,56],['c',34,23,45,65],['d',13,23,45,23]])
#       4 columns=(['team','round1','round2','round3','round4'])
#       5 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/__init__.py in __getattr__(name)
#     262         return _SparseArray
#     263
# --> 264     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     265
#     266
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
y=np.array([35,25,25,15])
mylabels=['sic','am','eds','dt']
plt.pie(y,labels=mylabels)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.linspace(0,100,5)
print(x)
# Out:
# [  0.  25.  50.  75. 100.]
