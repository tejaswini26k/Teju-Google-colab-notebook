# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswini26k/Teju-Google-colab-notebook/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://docs.google.com/spreadsheets/d/1fxeYXTAA6C16G3RCO7Bi4jfIdg0R-e7-/edit?usp=sharing&ouid=100514229050218665571&rtpof=true&sd=true

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
mydataset={
    'batch':["c1","c2","c3","c4"],
    'strength':[21,19,21,23]
}
df=pd.DataFrame(mydataset)
print(df)
# Out:
#   batch  strength
# 0    c1        21
# 1    c2        19
# 2    c3        21
# 3    c4        23

# %%
import pandas as pd
result={"sic":55,"am":60,"eds":66}
sr=pd.Series(result)
print(sr)
# Out:
# sic    55
# am     60
# eds    66
# dtype: int64

# %%
import pandas as pd
result={"sic":55,"am":60,"eds":66}
sr=pd.Series(result,index=["sic","eds"])
print(sr)
# Out:
# sic    55
# eds    66
# dtype: int64

# %%
import pandas as pd
a=[10,70,20]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    10
# 1    70
# 2    20
# dtype: int64

# %%
import pandas as pd
data={
    "course":["sic","dt","eds","eng"],
    "credits":[4,3,4,2]
}
#load into a dataframe object:
df=pd.DataFrame(data)
print(df)
# Out:
#   course  credits
# 0    sic        4
# 1     dt        3
# 2    eds        4
# 3    eng        2

# %%
print(df.loc[0])
# Out:
# course     sic
# credits      4
# Name: 0, dtype: object

# %%
print(df.loc[[0,1]])
# Out:
#   course  credits
# 0    sic        4
# 1     dt        3

# %%
import pandas as pd
data={
    "city":["pune",'mumbai','nagpur','nashik'],
    "temperature":[38,40,45,42]
}
df=pd.DataFrame(data,index=["day1","day2","day3","day4"])
print(df)
# Out:
#         city  temperature
# day1    pune           38
# day2  mumbai           40
# day3  nagpur           45
# day4  nashik           42

# %%
import pandas as pd
df=pd.read_csv('/content/sales.csv')
print(df)
# Out:
#    Product ID Product details Supplier Details  Customer Details  Gender
# 0      P00001   Lenovo Laptop        Raka Ele.  Kaustubh Mahajan    Male
# 1      P00002     Samsung M31      Vijay Sales     Siddhi Kiwale  Female
# 2      P00003    Realmi 10pro        Gada Ele.  Sanket Kandalkar    Male
# 3      P00004        Oppo F21       Surya Ele.         Yash Mali    Male
# 4      P00005   Lenovo Laptop        Raka Ele.        Yash Bagul    Male
# 5      P00006     Samsung M31        Gada Ele.     Siddhi Kiwale  Female
# 6      P00007       LG TV 32"      Vijay Sales  Sanket Kandalkar    Male
# 7      P00008        Oppo F21       Surya Ele.  Kaustubh Mahajan    Male
# 8      P00009   Lenovo Laptop        Raka Ele.         Yash Mali    Male
# 9      P00010     Samsung M31        Gada Ele.     Siddhi Kiwale  Female
# 10     P00011       LG TV 32"       Surya Ele.  Sanket Kandalkar    Male
# 11     P00012   Lenovo Laptop        Raka Ele.  Kaustubh Mahajan    Male
# ...

# %%
import pandas as pd

df=pd.read_csv('/content/student.txt')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-21-f5591c2ed7b7> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df=pd.read_csv('/content/student.txt')
#       4
#       5 print(df.to_string())
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import pandas as pd
df=pd.read_json('/content/student.js')
print(df)
# Out:
#    sal  roll_number  prn_number
# 0  320          320       30045
# 1  420          335       50043
# 2  540          347       40042
# 3  750          328       40032
# 4  656          329       60052

# %%
import pandas as pd
df=pd.read_csv('/content/coffee.csv')
print(df)
# Out:
#                Country of Origin  Number of Bags  Bag Weight  Aroma  Flavor  \
# 0                       Colombia               1          35   8.58    8.50
# 1                         Taiwan               1          80   8.50    8.50
# 2                           Laos              19          25   8.33    8.42
# 3                     Costa Rica               1          22   8.08    8.17
# 4                       Colombia               2          24   8.33    8.33
# 5                      Guatemala               5          30   8.33    8.33
# 6                         Taiwan               1          27   8.33    8.17
# 7                         Taiwan               1          90   8.25    8.25
# 8                         Taiwan               1          30   8.08    8.08
# 9   Tanzania, United Republic Of             320          60   8.08    8.17
# 10                      Ethiopia              10          30   8.08    8.25
# ...

# %%
https://drive.google.com/drive/folders/1ODD4zyY44nPvJb1TRBhqKPSOHW6Pi3wo?usp=drive_link
                                             kaggle
                                             https://drive.google.com/drive/folders/1S5JNXa6IhfBHmOU8x_t6pdSmIJUGRLoq?usp=drive_link
https://docs.google.com/document/d/1wELmgLd2FIMmKnHWvmyLEvs463a9PUGQ/edit?usp=drive_link&ouid=100514229050218665571&rtpof=true&sd=true
https://docs.google.com/document/d/16Pu1OuF1sNZ0-DnGtT_JLcBG1cSYxRA_/edit?usp=drive_link&ouid=100514229050218665571&rtpof=true&sd=true

# %%
count_column = df.shape[1]
print(count_column)
# Out:
# 12

# %%
a=df[(df['Country of Origin']==max)]
print(a)
# Out:
# Empty DataFrame
# Columns: [Country of Origin, Number of Bags, Bag Weight, Aroma, Flavor, Aftertaste, Acidity, Balance, Sweetness, Moisture Percentage, Color, Category Two Defects]
# Index: []

# %%
1.How many bags of coffee is produced in Taiwan?
2. How many countries are yielding coffee as per this dataset?
3.Which country yields highest production of coffee?
4. Total production of coffee in kg
5. Average number of bags of coffee.
6.What is average aroma scale of coffee?
7. Lowest grade for flavor.
8. Average grade for acidity.
9. coffee with highest flavor grade.
10. How many countries are producing yellowish color coffee
11.How many countries are producing green color coffee
12.Minimum grade for balance.
13.sum of all category two effects
14.Highest moisture level
15.Average aftertaste grade

# %%
#5.Average number of bags of coffee.
average_number_of_bags=df['Number of Bags'].mean()
print(average_number_of_bags)
#6.What is average aroma scale of coffee?
average_aroma_scale=df['Aroma'].mean()
print(average_aroma_scale)
#7.Lowest grade for flavor.
lowest_grade_count=df['Flavor'].min()
print(lowest_grade_count)
#8.Average grade for acidity.
average_acidity=df['Acidity'].mean()
print(average_acidity)
#9coffee with highest flavor grade.
country_with_highest_flavour_grade=df['Flavor'].max()
print(country_with_highest_flavour_grade)
#10.How many countries are producing yellowish color coffee
count_countries=df[df['Color']=='yellowish'].count()
print("number of producing yellowish coffee",count_countries[[0]])
#11.How many countries are producing green color coffee
count_countries=df[df['Color']=='green'].count()
print("number of countries producing green coffee are", count_countries[[0]])
#12.Minimum grade for balance.
minimum_balance_grade=df['Balance'].min()
print(minimum_balance_grade)
#13.sum of all category two effects
all_category_two_effects=df['Category Two Defects'].sum()
print(all_category_two_effects)
#14.Highest moisture level
highest_moisture_level=df['Moisture Percentage'].max()
print(highest_moisture_level)
#15.Average aftertaste grade
average_aftertaste_grade=df['Aftertaste'].mean()
print(average_aftertaste_grade)
#16
lowest_moisture_level=df['Moisture Percentage'].min()
print(lowest_moisture_level)
#17
min_aftertaste_grade=df['Aftertaste'].min()
print(min_aftertaste_grade)
#18
min_number_of_bags=df['Number of Bags'].min()
print(min_number_of_bags)
#19.highest grade for acidity.
highest_acidity=df['Acidity'].max()
print(highest_acidity)
#20.
#12.all grade for balance.
all_balance_grade=df['Balance'].sum()
print(all_balance_grade)
# Out:
# 34.088235294117645
# 8.08
# 7.83
# 8.01529411764706
# 8.5
# number of producing yellowish coffee Country of Origin    2
# dtype: int64
# number of countries producing green coffee are Country of Origin    16
# dtype: int64
# 7.75
# 32
# 11.9
# 7.99235294117647
# 9.1
# 7.67
# 1
# 8.58
# 271.69

# %%
#1.sum of bags of cofee
sum_number_of_bags=df['Number of Bags'].sum()
print(sum_number_of_bags)

#2.number of countries yielding coffee
count_number_of_countries=df['Country of Origin'].count()
print(count_number_of_countries)
#3.Total production of coffee
sum_of_bags_weight=df['Bag Weight'].sum()
print(sum_of_bags_weight)
#4.average moisture level
average_moisture_level=df['Flavor'].mean()
print(average_moisture_level)
# Out:
# 1159
# 34
# 1340
# 8.110588235294117

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/purchase_data.csv')
print(data)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176559.0  Bose SoundSport Headphones               1.0       99.99
# 1   176560.0                Google Phone               1.0      600.00
# 2   176560.0            Wired Headphones               1.0       11.99
# 3   176561.0            Wired Headphones               1.0       11.99
# 4   176562.0        USB-C Charging Cable               1.0       11.95
# ..       ...                         ...               ...         ...
# 64  259329.0    Lightning Charging Cable               1.0       14.95
# 65  259330.0       AA Batteries (4-pack)               2.0        3.84
# 66  259331.0    Apple Airpods Headphones               1.0      150.00
# 67  259332.0    Apple Airpods Headphones               1.0      150.00
# 68  259333.0  Bose SoundSport Headphones               1.0       99.99
#
#           Order Date                        Purchase Address
# ...

# %%
#find nan
nan_df=data[data.isnull().any(axis=1)]
display(nan_df.head())
data=data.dropna(how='all')
data.head()
# Out:
#     Order ID Product  Quantity Ordered  Price Each Order Date Purchase Address
# 36       NaN     NaN               NaN         NaN        NaN              NaN
# 51       NaN     NaN               NaN         NaN        NaN              NaN
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001
# ...

# %%
https://docs.google.com/presentation/d/1vR4XFzkFeaxHD54f2ItJFz_0cqE_lVT_/edit?usp=sharing&ouid=100514229050218665571&rtpof=true&sd=true
https://drive.google.com/file/d/1gLjL193Iv-o00Zhy1B9vVFkXiZC7R639/view?usp=sharing

# %%
data=data[data['Order Date'].str[0:2]!='or']

# %%
data['Quantity Ordered']=pd.to_numeric(data['Quantity Ordered'])
data['Price Each']=pd.to_numeric(data['Price Each'])

# %%
data['Month']=data['Order Date'].str[0:2]
data['Month']=data['Month'].astype('int32')
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  Month
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215      4
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001      5
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016      4

# %%
import datetime as dt
data['Month 2']=pd.to_datetime(data['Order Date']).dt.month
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  Month  Month 2
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215      4        4
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4        4
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4        4
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001      5        5
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016      4        4

# %%
def get_city(address):
  return address.split(",")[1].strip("")
def get_state(address):
  return address.split(",")[2].split(" ")[1]

data['City']=data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
data.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0  176559.0  Bose SoundSport Headphones               1.0       99.99
# 1  176560.0                Google Phone               1.0      600.00
# 2  176560.0            Wired Headphones               1.0       11.99
# 3  176561.0            Wired Headphones               1.0       11.99
# 4  176562.0        USB-C Charging Cable               1.0       11.95
#
#          Order Date                        Purchase Address  Month  Month 2  \
# 0  04-07-2019 22:30       682 Chestnut St, Boston, MA 02215      4        4
# 1  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4        4
# 2  04-12-2019 14:38    669 Spruce St, Los Angeles, CA 90001      4        4
# 3     05/30/19 9:27       333 8th St, Los Angeles, CA 90001      5        5
# 4    04/29/19 13:03  381 Wilson St, San Francisco, CA 94016      4        4
#
#                    City
# 0          Boston  (MA)
# 1     Los Angeles  (CA)
# ...

# %%
data['Sales']=data['Quantity Ordered'].astype('int')*data['Price Each'].astype('float')

# %%
data.groupby(['Month']).sum()
# Out:
# <ipython-input-9-9f56799fde73>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Month']).sum()
#         Order ID  Quantity Ordered  Price Each  Month 2    Sales
# Month
# 4      7335546.0             123.0      885.80      160  1210.76
# 5       353124.0               2.0      111.98       10   111.98
# 6       184076.0               1.0       14.95        6    14.95
# 8       726962.0               9.0       23.92       32    50.83
# 9      2378802.0              17.0      591.44       90   616.62
# 10      550924.0              11.0       10.67       30    39.69
# 11      740314.0              19.0       13.66       44    65.31
# 12      550635.0              17.0        8.97       36    50.83

# %%
https://colab.research.google.com/drive/10y3JN0fgZ9oOUtfNB7YDL1kW6fCUKtkP?usp=sharing

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

data['City'] = data['Purchase Address'].apply(lambda x: f"{get_city(x)}")
data.head()
city_max=data.groupby(['City']).sum()
print(max(city_max))
# Out:
# Sales
# <ipython-input-10-b303a3e7536c>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   city_max=data.groupby(['City']).sum()

# %%
df = data[data['Order ID'].duplicated(keep=False)]

# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()
print(df['Grouped'])
# Out:
# 1    Google Phone,Wired Headphones
# 2    Google Phone,Wired Headphones
# Name: Grouped, dtype: object
# <ipython-input-11-2288d8e6336f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('Google Phone', 'Wired Headphones') 1

# %%
product_group = data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
# Out:
# <ipython-input-14-4058a2298ad5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity_ordered = product_group.sum()['Quantity Ordered']

# %%
print(quantity_ordered)
# Out:
# Product
# AA Batteries (4-pack)          64.0
# AAA Batteries (4-pack)        109.0
# Apple Airpods Headphones        3.0
# Bose SoundSport Headphones      3.0
# Google Phone                    1.0
# Lightning Charging Cable        4.0
# USB-C Charging Cable            8.0
# Wired Headphones                7.0
# Name: Quantity Ordered, dtype: float64

# %%
prices =data.groupby('Product').mean()['Price Each']
print(prices)
# Out:
# Product
# AA Batteries (4-pack)           3.84
# AAA Batteries (4-pack)          2.99
# Apple Airpods Headphones      150.00
# Bose SoundSport Headphones     99.99
# Google Phone                  600.00
# Lightning Charging Cable       14.95
# USB-C Charging Cable           11.95
# Wired Headphones               11.99
# Name: Price Each, dtype: float64
# <ipython-input-18-31bb98b403f5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   prices =data.groupby('Product').mean()['Price Each']

# %%
# %matplotlib inline

# %%
plt.style.use('classic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f0039759a9d0> in <cell line: 1>()
# ----> 1 plt.style.use('classic')
#
# NameError: name 'plt' is not defined

# %%
import pandas as pd
data=pd.read_csv('/content/coffee1.csv')
print(data)
# Out:
#     Unnamed: 0             Country of Origin  Number of Bags  Bag Weight  \
# 0            1                      Colombia             1.0        35.0
# 1            2                        Taiwan             1.0        80.0
# 2            3                          Laos            19.0        25.0
# 3            4                    Costa Rica             1.0        22.0
# 4            5                      Colombia             2.0        24.0
# 5            6                     Guatemala             5.0        30.0
# 6            7                        Taiwan             1.0        27.0
# 7            8                        Taiwan             1.0        90.0
# 8            9                        Taiwan             1.0        30.0
# 9           10  Tanzania, United Republic Of           320.0        60.0
# 10          11                      Ethiopia            10.0        30.0
# 11          12                     Guatemala             5.0        15.0
# ...

# %%
#find nan
nan_df=data[data.isnull().any(axis=1)]
display(nan_df.head())
data=data.dropna(how='all')
data.head()
# Out:
#     Unnamed: 0 Country of Origin  Number of Bags  Bag Weight  Aroma  Flavor  \
# 10          11          Ethiopia            10.0        30.0   8.08    8.25
# 13          14          Ethiopia            40.0        60.0   7.67    8.17
# 18          19               NaN             NaN         NaN    NaN     NaN
#
#     Aftertaste  Acidity  Balance  Sweetness  Moisture Percentage  \
# 10         8.0      NaN     7.92       10.0                 11.8
# 13         8.0     8.33     8.00        NaN                 11.6
# 18         NaN      NaN      NaN        NaN                  NaN
#
#             Color  Category Two Defects
# 10       greenish                   1.0
# 13  yellow- green                   2.0
# 18            NaN                   NaN
#    Unnamed: 0 Country of Origin  Number of Bags  Bag Weight  Aroma  Flavor  \
# 0           1          Colombia             1.0        35.0   8.58    8.50
# 1           2            Taiwan             1.0        80.0   8.50    8.50
# ...

# %%
data['Number of Bags']=pd.to_numeric(data['Number of Bags'])
data['Bag Weight']=pd.to_numeric(data['Bag Weight'])
data['Aroma']=pd.to_numeric(data['Aroma'])
data['Flavor']=pd.to_numeric(data['Flavor'])
data['Aftertaste']=pd.to_numeric(data['Aftertaste'])
data['Acidity']=pd.to_numeric(data['Acidity'])
data['Balance']=pd.to_numeric(data['Balance'])
data['Sweetness']=pd.to_numeric(data['Sweetness'])
data['Moisture Percentage']=pd.to_numeric(data['Moisture Percentage'])
data['Category Two Defects']=pd.to_numeric(data['Category Two Defects'])
data
# Out:
#     Unnamed: 0             Country of Origin  Number of Bags  Bag Weight  \
# 0            1                      Colombia             1.0        35.0
# 1            2                        Taiwan             1.0        80.0
# 2            3                          Laos            19.0        25.0
# 3            4                    Costa Rica             1.0        22.0
# 4            5                      Colombia             2.0        24.0
# 5            6                     Guatemala             5.0        30.0
# 6            7                        Taiwan             1.0        27.0
# 7            8                        Taiwan             1.0        90.0
# 8            9                        Taiwan             1.0        30.0
# 9           10  Tanzania, United Republic Of           320.0        60.0
# 10          11                      Ethiopia            10.0        30.0
# 11          12                     Guatemala             5.0        15.0
# ...

# %%
#1.sum of bags of cofee
sum_number_of_bags=data['Number of Bags'].sum()
print(sum_number_of_bags)

#2.number of countries yielding coffee
count_number_of_countries=data['Country of Origin'].count()
print(count_number_of_countries)

#3.Total production of coffee
sum_of_bags_weight=data['Bag Weight'].sum()
print(sum_of_bags_weight)

#4.average moisture level
average_moisture_level=data['Flavor'].mean()
print(average_moisture_level)
# Out:
# 1151.0
# 33
# 1339.0
# 8.10878787878788

# %%
#5.Average number of bags of coffee.
average_number_of_bags=data['Number of Bags'].mean()
print(average_number_of_bags)

#6.What is average aroma scale of coffee?
average_aroma_scale=data['Aroma'].mean()
print(average_aroma_scale)

#7.Lowest grade for flavor.
lowest_grade_count=data['Flavor'].min()
print(lowest_grade_count)

#8.Average grade for acidity.
average_acidity=data['Acidity'].mean()
print(average_acidity)

#9.coffee with highest flavor grade.
country_with_highest_flavour_grade=data['Flavor'].max()
print(country_with_highest_flavour_grade)

#10.How many countries are producing yellowish color coffee
count_countries=data[data['Color']=='yellowish'].count()
print("number of countries producing yellowish coffee",count_countries[[0]])

#11.How many countries are producing green color coffee
count_countries=data[data['Color']=='green'].count()
print("number of countries producing green coffee are", count_countries[[0]])

#12.Minimum grade for balance.
minimum_balance_grade=data['Balance'].min()
print(minimum_balance_grade)

#13.sum of all category two effects
all_category_two_effects=data['Category Two Defects'].sum()
print(all_category_two_effects)

#14.Highest moisture level
highest_moisture_level=data['Moisture Percentage'].max()
print(highest_moisture_level)

#15.Average aftertaste grade
average_aftertaste_grade=data['Aftertaste'].mean()
print(average_aftertaste_grade)

#16. Lowest moisture level
lowest_moisture_level=data['Moisture Percentage'].min()
print(lowest_moisture_level)

#17. minimum aftertaste grade
min_aftertaste_grade=data['Aftertaste'].min()
print(min_aftertaste_grade)

#18. minimum number of bags
min_number_of_bags=data['Number of Bags'].min()
print(min_number_of_bags)

#19.highest grade for acidity.
highest_acidity=data['Acidity'].max()
print(highest_acidity)

#20.Total grade for balance.
all_balance_grade=data['Balance'].sum()
print(all_balance_grade)
# Out:
# 34.878787878787875
# 8.08
# 7.83
# 8.01625
# 8.5
# number of countries producing yellowish coffee Unnamed: 0    2
# dtype: int64
# number of countries producing green coffee are Unnamed: 0    16
# dtype: int64
# 7.75
# 31.0
# 11.9
# 7.99969696969697
# 9.1
# 7.67
# 1.0
# 8.58
# 263.68999999999994

# %%
data['Country of Origin']=data['Color'].str[0:2]
data['Country of Origin']=data['Country of Origin'].astype('int32')
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-e3367a3f6aa5> in <cell line: 2>()
#       1 data['Country of Origin']=data['Color'].str[0:2]
# ----> 2 data['Country of Origin']=data['Country of Origin'].astype('int32')
#       3 data.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
